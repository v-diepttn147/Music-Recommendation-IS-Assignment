# %%
import os
import django
import sys
sys.path.append('..')
# Set the project settings module
os.environ['DJANGO_SETTINGS_MODULE'] = 'musicplayer.settings' 
os.environ['PYTHONPATH'] = os.getcwd()

# Initialize Django
django.setup()

# %%
from musicapp.models import Song

# %%
import pandas as pd

df = pd.read_pickle('../pickles/music1K5_with_youtube_search.pkl')

# %%
mapping_youtube_id_with_file_name = {}
files = os.listdir('../media/new_song/mp3_files')
for file in files:
    mapping_youtube_id_with_file_name[file[:11]] = file

# %%
from asgiref.sync import sync_to_async

# Wrap the create method in sync_to_async
async def add_song_async(row_data):
    new_song = await sync_to_async(Song.objects.create)(
        name=row_data['name'],
        album="",
        language="English",  # Adjust based on your model setup
        song_img=row_data['preview'],  # File path
        year=2024,
        singer=row_data['artist'],
        song_file=row_data['mp3_file']  # File path
    )
    print("New song added:", new_song)



from asgiref.sync import sync_to_async

# Wrap the delete method in sync_to_async
async def remove_song_async(song_name):
    try:
        # Fetch the song by name
        song_to_delete = await sync_to_async(Song.objects.get)(name=song_name)
        
        # Delete the song
        await sync_to_async(song_to_delete.delete)()
        
        print(f"Song '{song_name}' has been removed.")
    except Song.DoesNotExist:
        print(f"Song '{song_name}' does not exist.")

# %%
df.keys()
# Out:
# Index(['track_id', 'artist', 'song', 'duration_ms', 'explicit', 'year',
#        'imageURL', 'popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'genre', 'search_result'],
#       dtype='object')

# %%
df
# Out:
#                     track_id           artist  \
# 0     1JiR4RJaZlbZ5b3HG8jkeL           Wizkid
# 1     6cfNBFSKFB59wO8xIFZ0qI   Ivan komarenko
# 2     5VcFzH97JEHgXgedErp4cP     Jayla Darden
# 3     7oMBY3VmIxqNVeZ7yneYuN  Various Artists
# 4     3eDX2SnjVRG9hh0v074eEO  Various Artists
# ...                      ...              ...
# 1490  24MTNjIigzPJFJ3AAsYBNt  Various Artists
# 1491  34cmEDq5SNUTBwELbIiDeh  Various Artists
# 1492  0ATOzpyZ5IedrZ01QSrEgp  Various Artists
# 1493  2CHuu85IjdomB4wPkDwoZp           Josh A
# 1494  2XeApaynFKxg3wtfLKqYsa         Ministry
#
#                                              song  duration_ms  explicit  \
# 0                         Longtime (feat. Skepta)       239893      True
# 1                          Dom na wiślanym brzegu       209093     False
# 2                                        Idea 686       163235     False
# 3                               Me Voy Enamorando       235720     False
# 4                           Christmas Without You       197146     False
# ...                                           ...          ...       ...
# 1490  Nama Ramayana - Ragamalika - Mssubbulakshmi       691186     False
# 1491                          A Warm Summer Night       364853     False
# 1492                            Weekend Superstar       151826     False
# 1493                            Endless Nightmare       151308      True
# 1494             Same Old Madness (Video Version)       219726     False
#
#       year                                           imageURL  popularity  \
# 0     2020  https://i.scdn.co/image/ab67616d0000b27390e89e...          51
# 1     2010  https://i.scdn.co/image/ab67616d0000b273bd89a9...          15
# 2     2018  https://i.scdn.co/image/ab67616d0000b2738a4b10...          55
# 3     2022  https://i.scdn.co/image/ab67616d0000b27358067d...           0
# 4     2022  https://i.scdn.co/image/ab67616d0000b27389f796...           0
# ...    ...                                                ...         ...
# 1490  2009  https://i.scdn.co/image/ab67616d0000b27396a988...          31
# 1491  2022  https://i.scdn.co/image/ab67616d0000b273d6dd60...           0
# 1492  2022  https://i.scdn.co/image/ab67616d0000b273916196...           0
# 1493  2018  https://i.scdn.co/image/ab67616d0000b273a76458...          50
# 1494  2015  https://i.scdn.co/image/ab67616d0000b273a439df...          23
#
#       danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0            0.850   0.660  ...    -4.846     0       0.1690       0.41700
# 1            0.640   0.758  ...    -7.310     0       0.0675       0.49700
# 2            0.712   0.347  ...   -10.363     0       0.0410       0.37800
# 3            0.686   0.912  ...    -3.411     1       0.0685       0.05330
# 4            0.262   0.677  ...    -5.645     1       0.0528       0.44700
# ...            ...     ...  ...       ...   ...          ...           ...
# 1490         0.652   0.478  ...    -7.663     1       0.0553       0.96200
# 1491         0.591   0.569  ...   -12.680     0       0.0468       0.39700
# 1492         0.587   0.876  ...    -5.614     1       0.0684       0.24500
# 1493         0.728   0.573  ...    -8.388     1       0.0347       0.00732
# 1494         0.559   0.853  ...    -8.594     0       0.2750       0.01580
#
#       instrumentalness  liveness  valence    tempo       genre  \
# 0             0.000051    0.2090    0.622  101.947   dancehall
# 1             0.000000    0.0506    0.849  106.978       disco
# 2             0.021200    0.1110    0.500  135.975       chill
# 3             0.000000    0.3920    0.511   99.952     electro
# 4             0.000000    0.2050    0.365  207.478       piano
# ...                ...       ...      ...      ...         ...
# 1490          0.000024    0.7030    0.830  113.691   classical
# 1491          0.011100    0.1750    0.495  135.980       disco
# 1492          0.000000    0.3310    0.891  154.862     country
# 1493          0.000000    0.1640    0.316  139.944         emo
# 1494          0.009840    0.1160    0.811  201.759  industrial
#
#                                           search_result
# 0     {'result': [{'type': 'video', 'id': 'RPxw0nR9H...
# 1     {'result': [{'type': 'video', 'id': 'DHVCAnaUg...
# 2     {'result': [{'type': 'video', 'id': 'O-jpTQ3C7...
# 3     {'result': [{'type': 'video', 'id': '0yr75-gxV...
# 4     {'result': [{'type': 'video', 'id': 'wJAIQy5Ie...
# ...                                                 ...
# 1490  {'result': [{'type': 'video', 'id': 'gCXIUgHPd...
# 1491  {'result': [{'type': 'video', 'id': 'pdB0ngR-Z...
# 1492  {'result': [{'type': 'video', 'id': '34Na4j8AV...
# 1493  {'result': [{'type': 'video', 'id': 'u4H6936Nh...
# 1494  {'result': [{'type': 'video', 'id': '6KYkFflAw...
#
# [1495 rows x 21 columns]

# %%
for i in range(len(df)):
    row = df.iloc[i]
    try:
        search_result = row['search_result']
        link = search_result['result'][0].get('link')
        year = row['year']
        track_id = row['track_id']
        song_name = row['song']
        singer = row['artist']
        if link is not None:
            id = link.replace('https://www.youtube.com/watch?v=', '')
            # if title is None:
            title = mapping_youtube_id_with_file_name.get(id, None)
            #     continue
            mp3_file = f'new_song/mp3_files/{title}'
            preview_file = f'new_song/preview/{track_id}.png'
            if os.path.exists(os.path.join('../media',mp3_file)) and os.path.exists(os.path.join('../media',preview_file)):
                row_data = {
                    'name': song_name,
# New song added: 14
# New song added: Hunger
# New song added: Jarabe - Remastered
# New song added: Shepherd's Pipe Carol (Adapted by Chris Hazell)
# New song added: Boomerang
# New song added: Yes Yes Y'all
# New song added: The Wheel - Finale
# New song added: After Dark (feat. Fiora)
# New song added: The Boys Of Summer
# New song added: Howlin' for You
# New song added: Movement Schedule
# New song added: City’s Archives
# New song added: Retrida
# New song added: Waltz in C Minor (Only for Piano)
# New song added: Happinezz
# New song added: Haze of the Rum
# New song added: Feel So Close - Radio Edit
# New song added: The Only One
# New song added: Lighthouses - Ambient Version
# New song added: Sinto Sua Falta / Insegurança / Eu Nunca Amei Assim
# New song added: Public Restroom Attendant
# New song added: Little Bitch
# New song added: Rock Nena Linda (Rock Pretty Baby)
# New song added: A Lenda - Ao Vivo
# New song added: Castle On the Hill - Throttle Remix
# New song added: Desde el alma
# New song added: Held You Tight
# New song added: Teen Dost
# New song added: Forglem mig ej (vuggevise)
# New song added: The Only Exception
# New song added: 25
# New song added: Let's Stop Right Where We Are
# New song added: Another Ghost
# New song added: Feels Right
# New song added: By the Way
# New song added: A Great Ballerina
# New song added: Неудачное свидание
# New song added: Heroes
# New song added: UNTILL THE DAWN
# New song added: Late Night
# New song added: Ameba - Remasterizado 2007
# New song added: Lips Of An Angel
# New song added: Children Of The Night
# New song added: Vuiet De Negru Izvor
# New song added: Brahms' Lullaby
# New song added: Eugene Onegin, Op. 24, Act I Scene 1: No. 6b, Lensky's Arioso "Ya lyublyu Vas. Ya lyublyu Vas, Olga"
# New song added: No Eres Mi Guardian
# New song added: Resting
# New song added: Salió El Sol
# New song added: E Agora?
# New song added: Piano in the Sky
# New song added: Sugar Sugar
# New song added: 相愛很難 - 電影"男人四十"歌曲
# New song added: Guerra e Paz
# New song added: Hello Walls
# New song added: Salió El Sol
# New song added: Animals
# New song added: Feels Right
# New song added: Salió El Sol
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable

# %%
async def fetch_songs():
    songs = await sync_to_async(list)(Song.objects.all())
    for song in songs:
        print(song.name, song.singer)

await fetch_songs()
# Out:
# Asal Mein Darshan Raval
# Baarish Ash King, Shashaa Tirupati
# Soch Na Sake Arijit Singh, Tulsi Kumar
# Gulaabo Vishal Dadlani
# Ban Ja Tu Meri Rani Guru Randhawa
# Aaj Se Teri Arijit Singh
# Bekhayali Sachet Tandon
# Tujhe Kitna Chahne Lage Hum Arijit Singh
# Haaye Oye Ash King
# Sun Saathiya Divya Kumar, Priya Saraiya
# Tie Me Down Gryffin, Elle Duhe
# A Sky Full of Stars Coldplay
# The Ocean Mike Perry, Shy Martin
# Let Me Love You Justin Bieber, DJ Snake
# I Like Me Better Lauv
# Attention Charlie Puth
# Girls Like You Maroon 5, Cardi B
# New Song Title Singer Name
# 0GVExpdmoDs-Maroon 5 - Animals (Lyrics).mp3 Neon Trees
# R8egmh5dWzo-Feel So Close (Radio Edit) - Calvin Harris.mp3 Calvin Harris
# R8egmh5dWzo-Feel So Close (Radio Edit) - Calvin Harris.mp3 Calvin Harris
